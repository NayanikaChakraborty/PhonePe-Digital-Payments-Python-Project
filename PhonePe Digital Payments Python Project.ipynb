# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Task 1: Data Loading and Understanding

# %% [markdown]
# ## Question 1.1: Load each dataset and display its structure

# %% [markdown]
# #### 1. Load the State_Txn and Users dataset and display its first 5 rows.

# %%
## Loading the State_Txn and Users dataset
State_txn_and_users = pd.read_csv('State_Txn and Users.csv')

# %%
## Displaying first 5 rows of the State_Txn and Users dataset
print("First 5 rows of the State_Txn and Users dataset :")
State_txn_and_users.head(5)
# Out:
# First 5 rows of the State_Txn and Users dataset :
#                        State  Year  Quarter  Transactions  Amount (INR)  \
# 0  Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1  Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2  Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3  Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4  Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
#
#      ATV (INR)  Registered Users  App Opens
# 0  2197.621091              6740          0
# 1  2498.989022              9405          0
# 2  3415.768284             12149          0
# 3  3811.277720             15222          0
# 4  3355.630147             18596          0

# %% [markdown]
# #### 2.  Load the State_TxnSplit dataset and display its bottom 10 rows.

# %%
## Loading the State_TxnSplit dataset
State_txnsplit = pd.read_csv('State_TxnSplit.csv')

# %%
## Displaying bottom 10 rows of the State_TxnSplit dataset
print("Bottom 10 rows of the State_TxnSplit dataset :")
State_txnsplit.tail(10)
# Out:
# Bottom 10 rows of the State_TxnSplit dataset :
#             State  Year  Quarter          Transaction Type  Transactions  \
# 2504  West Bengal  2021        1     Peer-to-peer payments      53869075
# 2505  West Bengal  2021        1         Merchant payments      37143701
# 2506  West Bengal  2021        1  Recharge & bill payments      26673733
# 2507  West Bengal  2021        1        Financial Services        166727
# 2508  West Bengal  2021        1                    Others        400816
# 2509  West Bengal  2021        2     Peer-to-peer payments      64661051
# 2510  West Bengal  2021        2         Merchant payments      41696787
# 2511  West Bengal  2021        2  Recharge & bill payments      34799709
# 2512  West Bengal  2021        2        Financial Services        190537
# 2513  West Bengal  2021        2                    Others        549353
#
#       Amount (INR)    ATV (INR)
# 2504  2.022400e+11  3754.292226
# 2505  2.891834e+10   778.553104
# ...

# %% [markdown]
# #### 3. Load the State_DeviceData dataset and display 10 rows from the middle of the dataset.

# %%
## Loading the State_DeviceData dataset
State_devicedata = pd.read_csv('State_DeviceData.csv')

# %%
## Finding the middle index of the State_DeviceData dataset
print(len(State_devicedata))

middle_index = len(State_devicedata)/2
middle_index = int(middle_index)
print(middle_index)

## Displaying 10 rows from the middle of the State_DeviceData dataset
print("10 rows from the middle of the State_DeviceData dataset :")
State_devicedata.iloc[middle_index : middle_index+10]
# Out:
# 5544
# 2772
# 10 rows from the middle of the State_DeviceData dataset :
#             State  Year  Quarter    Brand  Registered Users  Percentage
# 2772  Lakshadweep  2018        1  Samsung               102    0.203593
# 2773  Lakshadweep  2018        1   Xiaomi               100    0.199601
# 2774  Lakshadweep  2018        1     Vivo                67    0.133733
# 2775  Lakshadweep  2018        1     Oppo                56    0.111776
# 2776  Lakshadweep  2018        1   Huawei                25    0.049900
# 2777  Lakshadweep  2018        1  OnePlus                22    0.043912
# 2778  Lakshadweep  2018        1    Apple                20    0.039920
# 2779  Lakshadweep  2018        1   Realme                20    0.039920
# 2780  Lakshadweep  2018        1   Gionee                12    0.023952
# 2781  Lakshadweep  2018        1  COOLPAD                10    0.019960

# %% [markdown]
# #### 4. Load the District_Txn and Users dataset and display its first 10 rows and last 10 rows.

# %%
## Loading the District_Txn and Users dataset
District_txn_and_users = pd.read_csv('District_Txn and Users.csv')

# %%
## Finding first 10 rows and last 10 rows of the District_Txn and Users dataset
top_rows = District_txn_and_users.head(10)
bottom_rows = District_txn_and_users.tail(10)
top_and_bottom_rows = pd.concat([top_rows,bottom_rows])

## Displaying first 10 rows and last 10 rows of the dataset
print("First 10 rows and last 10 rows of the District_Txn and Users dataset :")
top_and_bottom_rows
# Out:
# First 10 rows and last 10 rows of the District_Txn and Users dataset :
#                            State  Year  Quarter                    District  \
# 0      Andaman & Nicobar Islands  2018        1                    Nicobars
# 1      Andaman & Nicobar Islands  2018        1    North And Middle Andaman
# 2      Andaman & Nicobar Islands  2018        1               South Andaman
# 3      Andaman & Nicobar Islands  2018        2                    Nicobars
# 4      Andaman & Nicobar Islands  2018        2    North And Middle Andaman
# 5      Andaman & Nicobar Islands  2018        2               South Andaman
# 6      Andaman & Nicobar Islands  2018        3                    Nicobars
# 7      Andaman & Nicobar Islands  2018        3    North And Middle Andaman
# 8      Andaman & Nicobar Islands  2018        3               South Andaman
# 9      Andaman & Nicobar Islands  2018        4                    Nicobars
# ...

# %% [markdown]
# #### 5. Load the District Demographics dataset and display every 10th row.

# %%
## Loading the District Demographics dataset
District_demographics = pd.read_csv('District Demographics.csv')

# %%
## Displaying every 10th row of the District_Demographics dataset
print("Every 10th row of the District_Demographics dataset :")
District_demographics.iloc[9::10]
# Out:
# Every 10th row of the District_Demographics dataset :
#                          State       District     Headquarters  Population  \
# 9               Andhra Pradesh     Srikakulam       Srikakulam     2699471
# 19           Arunachal Pradesh   Kurung Kumey        Koloriang       89717
# 29           Arunachal Pradesh       Shi Yomi             Tato       13310
# 39                       Assam         Bajali         Pathsala      253816
# 49                       Assam      Dibrugarh        Dibrugarh     1327748
# ..                         ...            ...              ...         ...
# 699  Andaman & Nicobar Islands  South Andaman       Port Blair      238142
# 709            Jammu & Kashmir      Ganderbal        Ganderbal      297003
# 719            Jammu & Kashmir          Reasi            Reasi      314714
# 729                      Delhi      New Delhi  Connaught Place      142004
# 739                 Puducherry           Mahé             Mahé       41816
#
# ...

# %% [markdown]
# ## Question 1.2: Display basic statistics and data types for each dataset

# %% [markdown]
# #### 1. For each dataset, display the summary statistics (mean, median, std, etc.) for numerical columns.

# %%
## Summary statistics for numerical columns of State_Txn and Users dataset
print("Summary statistics for numerical columns of the State_Txn and Users dataset :")
State_txn_and_users.describe()
# Out:
# Summary statistics for numerical columns of the State_Txn and Users dataset :
#               Year     Quarter  Transactions  Amount (INR)    ATV (INR)  \
# count   504.000000  504.000000  5.040000e+02  5.030000e+02   504.000000
# mean   2019.285714    2.357143  4.074000e+07  7.083332e+10  1993.471543
# std       1.031181    1.109971  8.228714e+07  1.440902e+11   607.464894
# min    2018.000000    1.000000  7.780000e+02  1.928611e+06     0.000000
# 25%    2018.000000    1.000000  5.925578e+05  1.167157e+09  1598.910667
# 50%    2019.000000    2.000000  6.217487e+06  1.051605e+10  1861.380589
# 75%    2020.000000    3.000000  4.363675e+07  6.947045e+10  2259.087924
# max    2021.000000    4.000000  5.736165e+08  1.027960e+12  3938.733850
#
#        Registered Users     App Opens
# count      5.040000e+02  5.040000e+02
# mean       4.777501e+06  9.774471e+07
# std        6.644496e+06  2.042376e+08
# min        5.010000e+02  0.000000e+00
# 25%        1.574202e+05  0.000000e+00
# ...

# %%
## Summary statistics for numerical columns of the State_TxnSplit dataset
print("Summary statistics for numerical columns of the State_TxnSplit dataset :")
State_txnsplit.describe()
# Out:
# Summary statistics for numerical columns of the State_TxnSplit dataset :
#               Year      Quarter  Transactions  Amount (INR)    ATV (INR)
# count  2514.000000  2514.000000  2.514000e+03  2.514000e+03  2514.000000
# mean   2019.286794     2.358393  8.167446e+06  1.443978e+10  1349.927929
# std       1.030807     1.109251  2.423645e+07  5.995055e+10  1534.866221
# min    2018.000000     1.000000  2.000000e+00  3.439721e+01    17.198606
# 25%    2018.000000     1.000000  2.788075e+04  1.762412e+07   385.735828
# 50%    2019.000000     2.000000  2.687980e+05  1.901189e+08   720.940406
# 75%    2020.000000     3.000000  3.683230e+06  2.661248e+09  1352.790116
# max    2021.000000     4.000000  2.795990e+08  8.721520e+11  7767.539936

# %%
## Summary statistics for numerical columns of the State_DeviceData dataset
print("Summary statistics for numerical columns of the State_DeviceData dataset :")
State_devicedata.describe()
# Out:
# Summary statistics for numerical columns of the State_DeviceData dataset :
#               Year      Quarter  Registered Users   Percentage
# count  5544.000000  5544.000000      5.544000e+03  5544.000000
# mean   2019.285714     2.357143      4.343183e+05     0.090909
# std       1.030250     1.108970      9.056069e+05     0.083095
# min    2018.000000     1.000000      1.000000e+01     0.006373
# 25%    2018.000000     1.000000      8.055750e+03     0.021588
# 50%    2019.000000     2.000000      7.442250e+04     0.056914
# 75%    2020.000000     3.000000      3.978875e+05     0.143626
# max    2021.000000     4.000000      9.764252e+06     0.478367

# %%
## Summary statistics for numerical columns of the District_Txn and Users dataset
print("Summary statistics for numerical columns of the District_Txn and Users dataset :")
District_txn_and_users.describe()
# Out:
# Summary statistics for numerical columns of the District_Txn and Users dataset :
#                Year       Quarter  Transactions  Amount (INR)     ATV (INR)  \
# count  10248.000000  10248.000000  1.024800e+04  1.024800e+04  10244.000000
# mean    2019.285714      2.357143  2.003607e+06  3.542311e+09   1909.796545
# std        1.030208      1.108924  9.613466e+06  1.473153e+10    600.943349
# min     2018.000000      1.000000  0.000000e+00  0.000000e+00     84.944283
# 25%     2018.000000      1.000000  1.031418e+05  1.756668e+08   1554.589051
# 50%     2019.000000      2.000000  3.763065e+05  6.784562e+08   1863.135530
# 75%     2020.000000      3.000000  1.272815e+06  2.377256e+09   2203.083552
# max     2021.000000      4.000000  3.487128e+08  4.444220e+11  11209.980550
#
#        Registered Users     App Opens
# count      1.024800e+04  1.024800e+04
# mean       2.349591e+05  4.807117e+06
# std        4.605978e+05  1.562541e+07
# min        2.200000e+01  0.000000e+00
# ...

# %%
## Summary statistics for numerical columns of the District Demographics dataset
print("Summary statistics for numerical columns of the District Demographics dataset :")
District_demographics.describe()
# Out:
# Summary statistics for numerical columns of the District Demographics dataset :
#          Population  Area (sq km)       Density
# count  7.420000e+02    742.000000    742.000000
# mean   1.668555e+06   4395.376011    838.512129
# std    1.458849e+06   4254.675870   2754.406896
# min    0.000000e+00      0.000000      0.000000
# 25%    6.530815e+05   2039.750000    198.000000
# 50%    1.322359e+06   3402.500000    353.000000
# 75%    2.297440e+06   5432.750000    686.250000
# max    1.008285e+07  45652.000000  36155.000000

# %% [markdown]
# #### 2. Display the data types of each column in each dataset.

# %%
## Data types of each column in the State_Txn and Users dataset
print("Data types of each column in the State_Txn and Users dataset :")
State_txn_and_users.dtypes
# Out:
# Data types of each column in the State_Txn and Users dataset :
# State                object
# Year                  int64
# Quarter               int64
# Transactions          int64
# Amount (INR)        float64
# ATV (INR)           float64
# Registered Users      int64
# App Opens             int64
# dtype: object

# %%
## Data types of each column in the State_TxnSplit dataset
print("Data types of each column in the State_TxnSplit dataset :")
State_txnsplit.dtypes
# Out:
# Data types of each column in the State_TxnSplit dataset :
# State                object
# Year                  int64
# Quarter               int64
# Transaction Type     object
# Transactions          int64
# Amount (INR)        float64
# ATV (INR)           float64
# dtype: object

# %%
## Data types of each column in the State_DeviceData dataset
print("Data types of each column in the State_DeviceData dataset :")
State_devicedata.dtypes
# Out:
# Data types of each column in the State_DeviceData dataset :
# State                object
# Year                  int64
# Quarter               int64
# Brand                object
# Registered Users      int64
# Percentage          float64
# dtype: object

# %%
## Data types of each column in the District_Txn and Users dataset
print("Data types of each column in the District_Txn and Users dataset :")
District_txn_and_users.dtypes
# Out:
# Data types of each column in the District_Txn and Users dataset :
# State                object
# Year                  int64
# Quarter               int64
# District             object
# Code                 object
# Transactions          int64
# Amount (INR)        float64
# ATV (INR)           float64
# Registered Users      int64
# App Opens             int64
# dtype: object

# %%
## Data types of each column in the District Demographics dataset
print("Data types of each column in the District Demographics dataset :")
District_demographics.dtypes
# Out:
# Data types of each column in the District Demographics dataset :
# State             object
# District          object
# Headquarters      object
# Population         int64
# Area (sq km)       int64
# Density            int64
# Code              object
# Alternate Name    object
# dtype: object

# %% [markdown]
# ## Question 1.3: Check for missing values

# %% [markdown]
# #### 1. Identify any missing values in each dataset.

# %%
## Identifying missing values in the State_Txn and Users dataset
print("Total missing values in each column of the State_Txn and Users dataset :")
State_txn_and_users.isnull().sum()
# Out:
# Total missing values in each column of the State_Txn and Users dataset :
# State               0
# Year                0
# Quarter             0
# Transactions        0
# Amount (INR)        1
# ATV (INR)           0
# Registered Users    0
# App Opens           0
# dtype: int64

# %%
## Identifying missing values in the State_TxnSplit dataset
print("Total missing values in each column of the State_TxnSplit dataset :")
State_txnsplit.isnull().sum()
# Out:
# Total missing values in each column of the State_TxnSplit dataset :
# State               0
# Year                0
# Quarter             0
# Transaction Type    0
# Transactions        0
# Amount (INR)        0
# ATV (INR)           0
# dtype: int64

# %%
## Identifying missing values in the State_DeviceData dataset
print("Total missing values in each column of the State_DeviceData dataset :")
State_devicedata.isnull().sum()
# Out:
# Total missing values in each column of the State_DeviceData dataset :
# State               0
# Year                0
# Quarter             0
# Brand               0
# Registered Users    0
# Percentage          0
# dtype: int64

# %%
## Identifying missing values in the District_Txn and Users dataset
print("Total missing values in each column of the District_Txn and Users dataset :")
District_txn_and_users.isnull().sum()
# Out:
# Total missing values in each column of the District_Txn and Users dataset :
# State                0
# Year                 0
# Quarter              0
# District             0
# Code                28
# Transactions         0
# Amount (INR)         0
# ATV (INR)            4
# Registered Users     0
# App Opens            0
# dtype: int64

# %%
## Identifying missing values in the District_Demographics dataset
print("Total missing values in each column of the District_Demographics dataset :")
District_demographics.isnull().sum()
# Out:
# Total missing values in each column of the District_Demographics dataset :
# State             0
# District          0
# Headquarters      0
# Population        0
# Area (sq km)      0
# Density           0
# Code              0
# Alternate Name    0
# dtype: int64

# %% [markdown]
# #### 2. Calculate the percentage of missing values for each column that has missing values.

# %%
## Calculating the percentage of missing values for each column that has missing values in the State_Txn and Users dataset
print("The percentage of missing values for each column that has missing values in the State_Txn and Users dataset :")
State_txn_and_users.isnull().mean()[State_txn_and_users.isnull().mean()>0]*100
# Out:
# The percentage of missing values for each column that has missing values in the State_Txn and Users dataset :
# Amount (INR)    0.198413
# dtype: float64

# %%
## Calculating the percentage of missing values for each column that has missing values in the District_Txn and Users dataset
print("The percentage of missing values for each column that has missing values in the District_Txn and Users dataset :")
District_txn_and_users.isnull().mean()[District_txn_and_users.isnull().mean()>0]*100
# Out:
# The percentage of missing values for each column that has missing values in the District_Txn and Users dataset :
# Code         0.273224
# ATV (INR)    0.039032
# dtype: float64

# %% [markdown]
# #### 3. Highlight which column has the highest percentage of missing values in each dataset.

# %%
## Highlighting the column with highest percentage of missing values in the State_Txn and Users dataset
State_txn_and_users_missing_value_percentage = State_txn_and_users.isnull().mean()[State_txn_and_users.isnull().mean()>0]*100

column_name = State_txn_and_users_missing_value_percentage.nlargest(n=1).index[0]
print("The column with highest percentage of missing values in the State_Txn and Users dataset :")
print(column_name)
# Out:
# The column with highest percentage of missing values in the State_Txn and Users dataset :
# Amount (INR)

# %%
## Highlighting the column with highest percentage of missing values in the District_Txn and Users dataset
District_txn_and_users_missing_value_percentage = District_txn_and_users.isnull().mean()[District_txn_and_users.isnull().mean()>0]*100

column_name = District_txn_and_users_missing_value_percentage.nlargest(n=1).index[0]
print("The column with highest percentage of missing values in the District_Txn and Users dataset :")
print(column_name)
# Out:
# The column with highest percentage of missing values in the District_Txn and Users dataset :
# Code

# %% [markdown]
# ### Conclusion :

# %% [markdown]
# #### State_Txn and Users dataset has only one missing value in its Amount(INR) column.
# #### State_TxnSplit, State_DeviceData, District Demographics datasets have no missing value.
# #### There are 28 and 4 missing values in Code column and ATV(INR) column respectively in District_Txn and Users dataset.
# #### In State_Txn and Users dataset, Amount(INR) column has the highest percentage of missing values as it is the only column with missing values.
# #### In District_Txn and Users dataset, Code column has the highest percentage of missing values.

# %% [markdown]
# ## Question 1.4: Create a summary

# %% [markdown]
# #### 1. Calculate the total number of states and the total number of districts.

# %%
## Calculating the total number of states and the total number of districts
Total_states = District_demographics['State'].nunique()
Total_districts = District_demographics['Code'].nunique()

print("Total number of states :",Total_states)
print("Total number of districts :",Total_districts)
# Out:
# Total number of states : 36
# Total number of districts : 742

# %% [markdown]
# #### 2. Identify the state with the highest number of districts.

# %%
## Calculating total number of districts for each state
Districts_per_state = District_txn_and_users.groupby('State').aggregate({'District':'nunique'})

## Finding the state with highest number of districts
state_with_max_district = Districts_per_state.nlargest(n=1,columns='District').index[0]

print("The state with the highest number of districts :")
print(state_with_max_district)
# Out:
# The state with the highest number of districts :
# Uttar Pradesh

# %% [markdown]
# ### Conclusion :

# %% [markdown]
# #### The total number of states and the total number of districts are 36 and 742 respectively.
# #### Uttar Pradesh has the highest number of districts.

# %% [markdown]
# # Task 2: Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Question 2.1: Analyze transaction trends over the years for each state.

# %% [markdown]
# #### 1. Calculate the total number of transactions and total transaction amount for each state over the years. Display the results in a tabular format.

# %%
## Finding the row with the null value
State_txn_and_users[State_txn_and_users['Amount (INR)'].isnull()]
# Out:
#              State  Year  Quarter  Transactions  Amount (INR)  ATV (INR)  \
# 26  Andhra Pradesh  2021        1     289747970           NaN        0.0
#
#     Registered Users  App Opens
# 26          18363733  957709447

# %%
## Calculating the value to replace the null value
AP_data = State_txnsplit.iloc[130:135,:]
AP_Amt = AP_data['Amount (INR)'].sum()
AP_Amt
# Out:
# 672444477163.1

# %%
## Replacing the null value
State_txn_and_users['Amount (INR)']=State_txn_and_users['Amount (INR)'].fillna(AP_Amt)

# %%
## Calculating the total number of transactions and total transaction amount for each state over the years.
State_txn_trends = State_txn_and_users.groupby(['State','Year']).aggregate({'Transactions':'sum','Amount (INR)':'sum'})
State_txn_trends

## Displaying the results
print("The total number of transactions and total transaction amount for each state over the years :")
State_txn_trends
# Out:
# The total number of transactions and total transaction amount for each state over the years :
#                                 Transactions  Amount (INR)
# State                     Year
# Andaman & Nicobar Islands 2018         58021  1.890761e+08
#                           2019        133104  4.734648e+08
#                           2020        446274  1.296423e+09
#                           2021        586166  1.682854e+09
# Andhra Pradesh            2018      77779112  1.220720e+11
# ...                                      ...           ...
# Uttarakhand               2021      44608834  7.727901e+10
# West Bengal               2018     120011635  1.115887e+11
#                           2019     257900590  2.660145e+11
#                           2020     304222327  5.527303e+11
#                           2021     260151489  5.223720e+11
#
# [144 rows x 2 columns]

# %% [markdown]
# #### 2. Identify the top 5 states with the highest transaction volumes and the top 5 states with the lowest transaction volumes. Display the results.

# %%
## Calculating total number of transactions for each state
State_txn = State_txn_trends.groupby('State').aggregate({'Transactions':'sum'})

# %%
## Calculating top 5 states with highest transaction volumes
top_5_highest = State_txn.nlargest(n=5, columns='Transactions')

## Displaying the results
print("The top 5 states with the highest transaction volumes :")
top_5_highest
# Out:
# The top 5 states with the highest transaction volumes :
#                 Transactions
# State
# Karnataka         2981044533
# Maharashtra       2833670154
# Telangana         2347430243
# Andhra Pradesh    1781091169
# Rajasthan         1382918930

# %%
## Calculating top 5 states with lowest transaction volumes
top_5_lowest = State_txn.nsmallest(n=5, columns ='Transactions')

## Displaying the results
print("The top 5 states with the lowest transaction volumes :")
top_5_lowest
# Out:
# The top 5 states with the lowest transaction volumes :
#                            Transactions
# State
# Lakshadweep                       71610
# Andaman & Nicobar Islands       1223565
# Ladakh                          1880109
# Mizoram                         2162776
# Meghalaya                       5648913

# %% [markdown]
# ## Question 2.2: Identify the most common transaction types in each state and quarter

# %% [markdown]
# #### 1. For each state and quarter, determine the most frequent transaction type. Display the results in a tabular format.

# %%
## Creating the required dataset
data = State_txnsplit[['State','Year','Quarter','Transaction Type','Transactions']]

# %%
## Identifying the most common transaction types in each state and quarter
common_txn_type = data.loc[data.groupby(['State','Year','Quarter'])['Transactions'].idxmax()]

## Displaying the results
print("The most common transaction types in each state and quarter :")
common_txn_type
# Out:
# The most common transaction types in each state and quarter :
#                           State  Year  Quarter          Transaction Type  \
# 0     Andaman & Nicobar Islands  2018        1  Recharge & bill payments
# 5     Andaman & Nicobar Islands  2018        2  Recharge & bill payments
# 10    Andaman & Nicobar Islands  2018        3  Recharge & bill payments
# 15    Andaman & Nicobar Islands  2018        4  Recharge & bill payments
# 20    Andaman & Nicobar Islands  2019        1  Recharge & bill payments
# ...                         ...   ...      ...                       ...
# 2489                West Bengal  2020        2     Peer-to-peer payments
# 2494                West Bengal  2020        3     Peer-to-peer payments
# 2499                West Bengal  2020        4     Peer-to-peer payments
# 2504                West Bengal  2021        1     Peer-to-peer payments
# 2509                West Bengal  2021        2     Peer-to-peer payments
#
#       Transactions
# ...

# %% [markdown]
# ## Question 2.3: Determine the device brand with the highest number of registered users in each state

# %% [markdown]
# #### 1. Identify the device brand with the highest number of registered users in each state. Display the results in a tabular format.

# %%
## Creating the required data
data = State_devicedata[['State','Brand','Registered Users']]

# %%
## Determining the device brand with the highest number of registered users in each state
state_brand = data.groupby(['State','Brand']).aggregate({'Registered Users':'sum'})
state_top_brand = state_brand.loc[state_brand.groupby('State')['Registered Users'].idxmax()]
state_top_brand

## Displaying the results
print("The device brand with the highest number of registered users in each state :")
state_top_brand
# Out:
# The device brand with the highest number of registered users in each state :
#                                               Registered Users
# State                                Brand
# Andaman & Nicobar Islands            Xiaomi              97889
# Andhra Pradesh                       Xiaomi           40061549
# Arunachal Pradesh                    Xiaomi             437803
# Assam                                Xiaomi            6979357
# Bihar                                Xiaomi           33721314
# Chandigarh                           Xiaomi             896628
# Chhattisgarh                         Xiaomi            8763373
# Dadra & Nagar Haveli and Daman & Diu Xiaomi             638834
# Delhi                                Xiaomi           24114984
# Goa                                  Xiaomi            1208672
# Gujarat                              Xiaomi           28942157
# Haryana                              Xiaomi           21102142
# ...

# %% [markdown]
# ## Question 2.4: Create a list of the top district per state based on population

# %% [markdown]
# #### 1. For each state, identify the district with the highest population. Display the results in a tabular format.

# %%
## Creating the required data
population_data = District_demographics[['State','District','Population']]

# %%
## Identifying the district with the highest population in each state
max_populated_district = population_data.loc[population_data.groupby('State')['Population'].idxmax()]

## Displaying the results
print("The district with highest population in each state :")
max_populated_district
# Out:
# The district with highest population in each state :
#                                     State                District  Population
# 699             Andaman & Nicobar Islands           South Andaman      238142
# 2                          Andhra Pradesh           East Godavari     5151549
# 28                      Arunachal Pradesh              Papum Pare      176385
# 64                                  Assam                  Nagaon     2826006
# 97                                  Bihar                   Patna     5772804
# 700                            Chandigarh              Chandigarh     1055450
# 133                          Chhattisgarh                  Raipur     2160876
# 703  Dadra & Nagar Haveli and Daman & Diu  Dadra and Nagar Haveli      343709
# 732                                 Delhi        North West Delhi     3656539
# 138                                   Goa               North Goa      817761
# ...

# %% [markdown]
# #### 2. Create a column chart depicting the district with the highest population for each state.

# %%
## Creating a column chart depicting the district with the highest population for each state
plt.figure(figsize=(12,4))

sns.barplot(max_populated_district,x='District',y='Population', color='green')
plt.xticks(rotation=90)
plt.title('District with the highest population for each state')
plt.xlabel('Districts')
plt.ylabel('Population')

plt.show()

# %% [markdown]
# ## Question 2.5: Calculate the average transaction value (ATV) for each state

# %% [markdown]
# #### 1. Compute the average transaction value for each state. Display the results in a tabular format.

# %%
## Calculating the average transaction value for each state
Amt_and_txn = State_txn_and_users.groupby('State').aggregate({'Amount (INR)':'sum','Transactions':'sum'})
Avg_txn_value = Amt_and_txn['Amount (INR)']/ Amt_and_txn['Transactions']

## Changing the data type
State_wise_ATV = pd.DataFrame({'State':Avg_txn_value.index, 'Avg_txn_value(INR)':Avg_txn_value.values})

## Displaying the results
print("The average transaction value for each state :")
State_wise_ATV
# Out:
# The average transaction value for each state :
#                                    State  Avg_txn_value(INR)
# 0              Andaman & Nicobar Islands         2976.399178
# 1                         Andhra Pradesh         2167.374784
# 2                      Arunachal Pradesh         2766.333539
# 3                                  Assam         2277.175192
# 4                                  Bihar         2297.476643
# 5                             Chandigarh         2104.990740
# 6                           Chhattisgarh         1718.150602
# 7   Dadra & Nagar Haveli and Daman & Diu         1497.232192
# 8                                  Delhi         1631.939331
# 9                                    Goa         1808.372977
# 10                               Gujarat         1803.167986
# 11                               Haryana         1866.717434
# 12                      Himachal Pradesh         1846.955544
# 13                       Jammu & Kashmir         2430.351780
# ...

# %% [markdown]
# #### 2. Identify the top 5 states with the highest ATV and the top 5 states with the lowest ATV. Display the results.

# %%
## Calculating top 5 states with the highest ATV
top_5_highest_ATV = State_wise_ATV.nlargest(n=5, columns = 'Avg_txn_value(INR)')

## Displaying the results
print("The top 5 states with the highest ATV :")
top_5_highest_ATV
# Out:
# The top 5 states with the highest ATV :
#                         State  Avg_txn_value(INR)
# 17                     Ladakh         3514.146494
# 0   Andaman & Nicobar Islands         2976.399178
# 23                    Mizoram         2920.848684
# 21                    Manipur         2905.757930
# 24                   Nagaland         2794.140997

# %%
## Calculating top 5 states with the lowest ATV
top_5_lowest_ATV = State_wise_ATV.nsmallest(n=5, columns = 'Avg_txn_value(INR)')

## Displaying the results
print("The top 5 states with the lowest ATV :")
top_5_lowest_ATV
# Out:
# The top 5 states with the lowest ATV :
#                                    State  Avg_txn_value(INR)
# 15                             Karnataka         1463.042872
# 7   Dadra & Nagar Haveli and Daman & Diu         1497.232192
# 20                           Maharashtra         1514.288958
# 35                           West Bengal         1541.682105
# 8                                  Delhi         1631.939331

# %% [markdown]
# ## Question 2.6: Analyze app usage trends

# %% [markdown]
# #### 1. Calculate the total number of app opens over the years and quarters for each state. Display the results in a tabular format.

# %%
## Calculating the total number of app opens over the years and quarters for each state
App_opens = State_txn_and_users[['State','Year','Quarter','App Opens']]

## Displaying the results
print("The total number of app opens over the years and quarters for each state :")
App_opens
# Out:
# The total number of app opens over the years and quarters for each state :
#                          State  Year  Quarter  App Opens
# 0    Andaman & Nicobar Islands  2018        1          0
# 1    Andaman & Nicobar Islands  2018        2          0
# 2    Andaman & Nicobar Islands  2018        3          0
# 3    Andaman & Nicobar Islands  2018        4          0
# 4    Andaman & Nicobar Islands  2019        1          0
# ..                         ...   ...      ...        ...
# 499                West Bengal  2020        2  198589332
# 500                West Bengal  2020        3  246554831
# 501                West Bengal  2020        4  291721919
# 502                West Bengal  2021        1  316832674
# 503                West Bengal  2021        2  275341466
#
# [504 rows x 4 columns]

# %% [markdown]
# #### 2. Identify trends in app usage by creating a line plot showing the number of app opens over time for a selected state.

# %%
## Creating data of the number of app opens for Karnataka.
K_data = App_opens[App_opens['State']=='Karnataka']
K_data['Year-Qtr'] = K_data['Year'].astype(str)+'-'+K_data['Quarter'].astype(str)

print("The number of app opens over time for Karnataka :")
K_data[['Year-Qtr','App Opens']]
# Out:
# The number of app opens over time for Karnataka :
# C:\Users\nayan\AppData\Local\Temp\ipykernel_71896\2665010085.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   K_data['Year-Qtr'] = K_data['Year'].astype(str)+'-'+K_data['Quarter'].astype(str)
#     Year-Qtr   App Opens
# 210   2018-1           0
# 211   2018-2           0
# 212   2018-3           0
# 213   2018-4           0
# 214   2019-1           0
# 215   2019-2   113024811
# 216   2019-3   445683660
# 217   2019-4   569674870
# 218   2020-1   626488036
# 219   2020-2   490510075
# 220   2020-3   693683212
# 221   2020-4   935510690
# 222   2021-1  1084917385
# 223   2021-2  1051089714

# %%
## Creating a line plot showing the number of app opens over time for Karnataka.
plt.figure(figsize=(8,4))

plt.plot(K_data['Year-Qtr'],K_data['App Opens'],marker = '*', color = 'blue')
plt.xticks(rotation=45)
plt.title('Trends of app opens over time for Karnataka')
plt.xlabel('Year-Qtr')
plt.ylabel('App opens')

plt.grid(True)
plt.show()

# %% [markdown]
# ## Question 2.7: Distribution of transaction types.

# %% [markdown]
# #### 1. Create a bar chart showing the distribution of different transaction types for each state for the most recent quarter in the dataset.

# %%
## Creating the required data
recent_year = State_txnsplit[State_txnsplit['Year']==2021]
recent_year_qtr = recent_year[recent_year['Quarter']==2]

# %%
## plotting bar chart showing the distribution of different transaction types for each state.

plt.figure(figsize=(30,20))

sns.barplot(x='State',y='Transactions', hue = 'Transaction Type', data = recent_year_qtr)
plt.xticks(rotation =90)
plt.title('Distribution of different transaction types for each state')
plt.xlabel('State')
plt.ylabel('Transactions')
plt.show()

# %%
## data for those states which are not clearly visible in the above chart
AN = recent_year_qtr[0:5]
ArP = recent_year_qtr[10:15]
Chand = recent_year_qtr[25:30]
Dadra = recent_year_qtr[35:40]
Ladakh = recent_year_qtr[85:90]
Laksha = recent_year_qtr[90:95]
Manipur = recent_year_qtr[105:110]
Megha = recent_year_qtr[110:115]
Mizo= recent_year_qtr[115:120]
Naga = recent_year_qtr[120:125]
Pudu = recent_year_qtr[130:135]
Sikkim = recent_year_qtr[145:150]
Tripura = recent_year_qtr[160:165]

data_for_state = pd.concat([AN,ArP,Chand,Dadra,Ladakh,Laksha,Manipur,Megha,Mizo,Naga,Pudu,Sikkim,Tripura])
data_for_state
# Out:
#                           State  Year  Quarter          Transaction Type  \
# 65    Andaman & Nicobar Islands  2021        2     Peer-to-peer payments
# 66    Andaman & Nicobar Islands  2021        2  Recharge & bill payments
# 67    Andaman & Nicobar Islands  2021        2         Merchant payments
# 68    Andaman & Nicobar Islands  2021        2        Financial Services
# 69    Andaman & Nicobar Islands  2021        2                    Others
# ...                         ...   ...      ...                       ...
# 2299                    Tripura  2021        2     Peer-to-peer payments
# 2300                    Tripura  2021        2  Recharge & bill payments
# 2301                    Tripura  2021        2         Merchant payments
# 2302                    Tripura  2021        2        Financial Services
# 2303                    Tripura  2021        2                    Others
#
#       Transactions  Amount (INR)    ATV (INR)
# ...

# %%
## plotting a bar chart for those states which are not clearly visible in the above chart

plt.figure(figsize=(30,20))

sns.barplot(x='State',y='Transactions', hue = 'Transaction Type', data = data_for_state)
plt.xticks(rotation =90)
plt.title('Distribution of different transaction types for each state')
plt.xlabel('State')
plt.ylabel('Transactions')
plt.show()

# %% [markdown]
# ## Question 2.8: Find unique mapping between district name and district code

# %% [markdown]
# #### 1. Identify the unique mapping between district names and district codes from the dataset.

# %%
## Finding the unique mapping between district names and district codes from the dataset
unique_mapping = District_demographics[['District','Code']].drop_duplicates()

print("The unique mapping is :")
print(unique_mapping.head())
# Out:
# The unique mapping is :
#         District  Code
# 0      Anantapur  AP01
# 1       Chittoor  AP02
# 2  East Godavari  AP03
# 3         Guntur  AP04
# 4            YSR  AP13

# %% [markdown]
# #### 2. Create a CSV file containing the unique district name and district code mappings.

# %% [markdown]
# #### 3. Export the CSV file.

# %%
## Creating a CSV file containing the unique district name and district code mappings and exporting the CSV file

unique_mapping.to_csv('unique_mapping.csv', index=False)

print("Unique mapping between district names and district codes have been exported to 'unique_mapping.csv'")
# Out:
# Unique mapping between district names and district codes have been exported to 'unique_mapping.csv'

# %% [markdown]
# # Task 3: Data Quality Checks

# %% [markdown]
# ## Question 3.1: Ensure data consistency across state and district levels

# %% [markdown]
# #### 1. For each state, calculate the total number of transactions, total transaction amount, and total registered users by summing up the values from the district level data.

# %%
## Calculating the total number of transactions, total transaction amount, and total registered users for each state from the district level data
statedata_from_districtdata = District_txn_and_users.groupby('State').aggregate({'Transactions':'sum','Amount (INR)':'sum','Registered Users':'sum'})
statedata_from_districtdata.reset_index('State',inplace=True)

# %% [markdown]
# #### 2. Compare the results with the corresponding values at the state level to ensure they match

# %%
## Calculating the total number of transactions, total transaction amount, and total registered users for each state from the state level data
statedata_from_statedata = State_txn_and_users.groupby('State').aggregate({'Transactions':'sum','Amount (INR)':'sum','Registered Users':'sum'})
statedata_from_statedata.reset_index('State',inplace=True)

# %%
## Comparing these two datasets
merged_on_state = pd.merge(statedata_from_statedata, statedata_from_districtdata, left_on='State', right_on='State', how='left')
merged_on_txn = pd.merge(statedata_from_statedata, statedata_from_districtdata, left_on='Transactions', right_on='Transactions', how='left')
merged_on_amt = pd.merge(statedata_from_statedata, statedata_from_districtdata, left_on='Amount (INR)', right_on='Amount (INR)', how='left')
merged_on_users = pd.merge(statedata_from_statedata, statedata_from_districtdata, left_on='Registered Users', right_on='Registered Users', how='left')

# %%
## Merging the datasets based on State column
merged_on_state.head(2)
# Out:
#                        State  Transactions_x  Amount (INR)_x  \
# 0  Andaman & Nicobar Islands         1223565    3.641818e+09
# 1             Andhra Pradesh      1781091169    3.860292e+12
#
#    Registered Users_x  Transactions_y  Amount (INR)_y  Registered Users_y
# 0              408396         1223565    3.641818e+09              408396
# 1           158007957      1781091169    3.860292e+12           158007957

# %%
## Merging the datasets based on Transactions column
merged_on_txn.head(2)
# Out:
#                      State_x  Transactions  Amount (INR)_x  \
# 0  Andaman & Nicobar Islands       1223565    3.641818e+09
# 1             Andhra Pradesh    1781091169    3.860292e+12
#
#    Registered Users_x                    State_y  Amount (INR)_y  \
# 0              408396  Andaman & Nicobar Islands    3.641818e+09
# 1           158007957             Andhra Pradesh    3.860292e+12
#
#    Registered Users_y
# 0              408396
# 1           158007957

# %%
## Merging the datasets based on Amount column
merged_on_amt.head(2)
# Out:
#                      State_x  Transactions_x  Amount (INR)  \
# 0  Andaman & Nicobar Islands         1223565  3.641818e+09
# 1             Andhra Pradesh      1781091169  3.860292e+12
#
#    Registered Users_x State_y  Transactions_y  Registered Users_y
# 0              408396     NaN             NaN                 NaN
# 1           158007957     NaN             NaN                 NaN

# %%
## Merging the datasets based on Registered Users column
merged_on_users.head(2)
# Out:
#                      State_x  Transactions_x  Amount (INR)_x  \
# 0  Andaman & Nicobar Islands         1223565    3.641818e+09
# 1             Andhra Pradesh      1781091169    3.860292e+12
#
#    Registered Users                    State_y  Transactions_y  Amount (INR)_y
# 0            408396  Andaman & Nicobar Islands         1223565    3.641818e+09
# 1         158007957             Andhra Pradesh      1781091169    3.860292e+12

# %% [markdown]
# #### 3. Display any discrepancies found between the district-level and state-level data

# %%
print("In State-level dataset, some values in the Amount(INR) column are different from the values in the Amount (INR) column in district-level dataset.")
# Out:
# In State-level dataset, some values in the Amount(INR) column are different from the values in the Amount (INR) column in district-level dataset.

# %% [markdown]
# # Task 4: Data Merging and Advanced Analysis

# %% [markdown]
# ## Question 4.1: Ratio of users to population by state

# %% [markdown]
# #### 1. Merge State_Txn and Users dataset with the District Demographics dataset to calculate the ratio of registered users to the population for each state. Display the results in a tabular format.

# %%
## Merging State_Txn and Users dataset with the District Demographics dataset
Merged_data = pd.merge(State_txn_and_users, District_demographics, left_on='State', right_on='State', how='outer')
Merged_data.head(2)
# Out:
#                        State  Year  Quarter  Transactions  Amount (INR)  \
# 0  Andaman & Nicobar Islands  2018        1          6658   14631761.22
# 1  Andaman & Nicobar Islands  2018        1          6658   14631761.22
#
#      ATV (INR)  Registered Users  App Opens                  District  \
# 0  2197.621091              6740          0                   Nicobar
# 1  2197.621091              6740          0  North and Middle Andaman
#
#   Headquarters  Population  Area (sq km)  Density  Code  \
# 0  Car Nicobar       36842          1841       20  AN01
# 1   Mayabunder      105597          3736       28  AN02
#
#              Alternate Name
# 0                  Nicobars
# 1  North and Middle Andaman

# %%
## Creating the required data
state_total_population = Merged_data[['State','District','Population']].drop_duplicates()
state_population = state_total_population.groupby('State').aggregate({'Population':'sum'})

state_total_users = Merged_data[['State','Registered Users']].drop_duplicates()
total_registered_users = state_total_users.groupby('State').aggregate({'Registered Users':'sum'})

state_users_population = pd.merge(state_population, total_registered_users, left_on='State', right_on = 'State', how = 'outer')
state_users_population.head(2)
# Out:
#                            Population  Registered Users
# State
# Andaman & Nicobar Islands      380581            408396
# Andhra Pradesh               49378776         158007957

# %%
## Calculating the ratio
user_population_ratio = state_users_population['Registered Users']/state_users_population['Population']

# %%
## converting the datatype
print(type(user_population_ratio))
user_population_ratio=pd.DataFrame({'State':user_population_ratio.index,'User_Population_Ratio':user_population_ratio.values})
print(type(user_population_ratio))

## Displaying the results
print("The ratio of registered users to the population for each state :")
user_population_ratio
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# The ratio of registered users to the population for each state :
#                                    State  User_Population_Ratio
# 0              Andaman & Nicobar Islands               1.073086
# 1                         Andhra Pradesh               3.199916
# 2                      Arunachal Pradesh               1.159502
# 3                                  Assam               0.779445
# 4                                  Bihar               1.110451
# 5                             Chandigarh               3.601749
# 6                           Chhattisgarh               1.447675
# 7   Dadra & Nagar Haveli and Daman & Diu               4.601899
# 8                                  Delhi               5.681141
# 9                                    Goa               3.262156
# 10                               Gujarat               1.916872
# ...

# %% [markdown]
# #### 2. Create a column chart depicting the ratio of users to population by state.

# %%
## Creating a column chart depicting the ratio of users to population by state
plt.figure(figsize=(12,4))

sns.barplot(user_population_ratio,x='State',y='User_Population_Ratio',color = 'blue')
plt.xticks(rotation=90)
plt.title('the ratio of users to population by state')
plt.xlabel('State')
plt.ylabel('User_Population_Ratio')

plt.show()

# %% [markdown]
# ## Question 4.2: Correlate population density with transaction volume

# %% [markdown]
# #### 1. Merge the District_Txn and Users dataset with the District Demographics dataset.

# %%
## Replacing the null values in ATV (INR) column with 0 in District_Txn and Users dataset 
District_txn_and_users['ATV (INR)'] = District_txn_and_users['ATV (INR)'].fillna(0)
District_txn_and_users['Code'] = District_txn_and_users['Code'].fillna('Unknown')

# %%
## Merging the datasets
Merged_data = pd.merge(District_txn_and_users, District_demographics, left_on = 'Code', right_on = 'Code', how = 'outer')

# %%
Merged_data.dropna(inplace=True)
Merged_data.rename(columns={'State_y':'State','District_y':'District'},inplace=True)
Merged_data.head(2)
# Out:
#                      State_x    Year  Quarter District_x  Code  Transactions  \
# 0  Andaman & Nicobar Islands  2018.0      1.0   Nicobars  AN01         528.0
# 1  Andaman & Nicobar Islands  2018.0      2.0   Nicobars  AN01        1120.0
#
#    Amount (INR)    ATV (INR)  Registered Users  App Opens  \
# 0   1139848.801  2158.804548             262.0        0.0
# 1   3072436.908  2743.247239             351.0        0.0
#
#                        State District Headquarters  Population  Area (sq km)  \
# 0  Andaman & Nicobar Islands  Nicobar  Car Nicobar     36842.0        1841.0
# 1  Andaman & Nicobar Islands  Nicobar  Car Nicobar     36842.0        1841.0
#
#    Density Alternate Name
# 0     20.0       Nicobars
# 1     20.0       Nicobars

# %% [markdown]
# #### 2. Calculate the correlation between population density and transaction volume.

# %%
## Finding the required data
data = Merged_data[['State','District','Density','Transactions']]
Total_txn = data.groupby(['State','District']).aggregate({'Transactions':'sum'})
density_txn_data = pd.merge(data,Total_txn,left_on=['State','District'],right_on=['State','District'],how='outer')

density_txn_data.head(2)
# Out:
#                        State District  Density  Transactions_x  Transactions_y
# 0  Andaman & Nicobar Islands  Nicobar     20.0           528.0         59387.0
# 1  Andaman & Nicobar Islands  Nicobar     20.0          1120.0         59387.0

# %%
## Formatting the data
density_txn_data.drop(columns='Transactions_x',inplace=True)
print(density_txn_data.head(2))

density_txn_data.drop_duplicates(inplace=True)
print(density_txn_data.head(2))

density_txn_data.rename(columns={'Density':'Population_Density','Transactions_y':'Transaction_Volume'},inplace=True)
print(density_txn_data.head(2))
# Out:
#                        State District  Density  Transactions_y
# 0  Andaman & Nicobar Islands  Nicobar     20.0         59387.0
# 1  Andaman & Nicobar Islands  Nicobar     20.0         59387.0
#                         State                  District  Density  \
# 0   Andaman & Nicobar Islands                   Nicobar     20.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman     28.0
#
#     Transactions_y
# 0          59387.0
# 14        149394.0
#                         State                  District  Population_Density  \
# 0   Andaman & Nicobar Islands                   Nicobar                20.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman                28.0
#
#     Transaction_Volume
# 0              59387.0
# 14            149394.0

# %%
## Calculating correlation
print("The correlation between population density and transaction volume :")
density_txn_data.corr(numeric_only = True)
# Out:
# The correlation between population density and transaction volume :
#                     Population_Density  Transaction_Volume
# Population_Density            1.000000            0.250399
# Transaction_Volume            0.250399            1.000000

# %% [markdown]
# #### 3. Create a scatter plot to visualize the correlation between population density and transaction volume.

# %%
## Creating a scatter plot to visualize the correlation between population density and transaction volume
plt.figure(figsize=(3,3))

sns.scatterplot(data=density_txn_data, x='Population_Density', y='Transaction_Volume')
plt.xticks(rotation=90)
plt.title('Population_Density vs Transaction_Volume')
plt.xlabel('Population_Density')
plt.ylabel('Transaction_Volume')

plt.show()

# %% [markdown]
# #### Conclusion : Population Density has weak relationship with the number of Transactions, i.e., when Population Density increases (or decreases), the number of Transactions negligibly increases (or decreases).

# %% [markdown]
# ## Question 4.3: Average transaction amount per user

# %% [markdown]
# #### 1. Merge relevant datasets to calculate the average transaction amount per user for each state. Display the results in a tabular format.

# %%
## Creating the required data
Amt_user_data = State_txn_and_users.groupby('State').aggregate({'Amount (INR)':'sum','Registered Users':'sum'})
Amt_user_data.head(2)
# Out:
#                            Amount (INR)  Registered Users
# State
# Andaman & Nicobar Islands  3.641818e+09            408396
# Andhra Pradesh             3.860292e+12         158007957

# %%
## Calculating the average and changing the series into dataframe
avg_txn_amt = Amt_user_data['Amount (INR)']/Amt_user_data['Registered Users']

print(type(avg_txn_amt))
avg_txn_amt = pd.DataFrame({'State':avg_txn_amt.index, 'avg_txn_amt_per_user':avg_txn_amt.values})
print(type(avg_txn_amt))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
## Displaying the results
print("The average transaction amount per user for each state :")
avg_txn_amt
# Out:
# The average transaction amount per user for each state :
#                                    State  avg_txn_amt_per_user
# 0              Andaman & Nicobar Islands           8917.369075
# 1                         Andhra Pradesh          24430.998040
# 2                      Arunachal Pradesh          11949.126662
# 3                                  Assam          10476.576498
# 4                                  Bihar          14222.002687
# 5                             Chandigarh          14129.308175
# 6                           Chhattisgarh          11098.884128
# 7   Dadra & Nagar Haveli and Daman & Diu           6907.815954
# 8                                  Delhi          17299.579992
# 9                                    Goa           9309.966756
# 10                               Gujarat           8746.073384
# 11                               Haryana          12386.400602
# 12                      Himachal Pradesh           7317.601442
# ...

# %% [markdown]
# #### 2. Identify the top 5 states with the highest average transaction amount per user and the top 5 states with the lowest average transaction amount per user. Display the results.

# %%
## Calculating the top 5 states with the highest average transaction amount per user
top_5_highest = avg_txn_amt.nlargest(n=5, columns='avg_txn_amt_per_user')

## Displaying the results
print("Top 5 states with the highest average transaction amount per user :") 
top_5_highest
# Out:
# Top 5 states with the highest average transaction amount per user :
#              State  avg_txn_amt_per_user
# 31       Telangana          30653.516120
# 1   Andhra Pradesh          24430.998040
# 15       Karnataka          21474.282574
# 28       Rajasthan          17530.764404
# 8            Delhi          17299.579992

# %%
## Calculating the top 5 states with the lowest average transaction amount per user
top_5_lowest = avg_txn_amt.nsmallest(n=5, columns='avg_txn_amt_per_user')

## Displaying the results
print("Top 5 states with the lowest average transaction amount per user :")
top_5_lowest
# Out:
# Top 5 states with the lowest average transaction amount per user :
#                                    State  avg_txn_amt_per_user
# 18                           Lakshadweep           5614.898889
# 32                               Tripura           5727.184275
# 7   Dadra & Nagar Haveli and Daman & Diu           6907.815954
# 16                                Kerala           7274.846690
# 12                      Himachal Pradesh           7317.601442

# %% [markdown]
# ## Question 4.4: Device brand usage ratio

# %% [markdown]
# #### 1. Merge the State_DeviceData dataset with the State_Txn and Users dataset.

# %%
## Merging the State_DeviceData dataset with the State_Txn and Users dataset
Merged_data = pd.merge(State_txn_and_users, State_devicedata, left_on=['State','Year','Quarter'], right_on=['State','Year','Quarter'], how = 'outer')
Merged_data.head(2)
# Out:
#                        State  Year  Quarter  Transactions  Amount (INR)  \
# 0  Andaman & Nicobar Islands  2018        1          6658   14631761.22
# 1  Andaman & Nicobar Islands  2018        1          6658   14631761.22
#
#      ATV (INR)  Registered Users_x  App Opens    Brand  Registered Users_y  \
# 0  2197.621091                6740          0   Xiaomi                1665
# 1  2197.621091                6740          0  Samsung                1445
#
#    Percentage
# 0    0.247033
# 1    0.214392

# %% [markdown]
# #### 2. Calculate the ratio of users using each device brand to the total number of registered users in each state. Display the results in a tabular format.

# %%
## Creating the required data

data = Merged_data[['State','Year','Quarter','Registered Users_x','Brand','Registered Users_y']]

brand_user = data.groupby(['State','Brand']).aggregate({'Registered Users_y':'sum'})
brand_user.reset_index('Brand',inplace=True)

state_user_data=Merged_data[['State','Registered Users_x']].drop_duplicates()
total_user = state_user_data.groupby('State').aggregate({'Registered Users_x':'sum'})

Final_data = pd.merge(brand_user,total_user,left_on='State',right_on='State',how='left')

Final_data.head(2)
# Out:
#                             Brand  Registered Users_y  Registered Users_x
# State
# Andaman & Nicobar Islands   Apple                9334              408396
# Andaman & Nicobar Islands  Huawei               11497              408396

# %%
## Formatting the data

Final_data.rename(columns={'Registered Users_y':'Brand users','Registered Users_x':'Total users'},inplace = True)
Final_data.reset_index('State',inplace=True)

Final_data.head(2)
# Out:
#                        State   Brand  Brand users  Total users
# 0  Andaman & Nicobar Islands   Apple         9334       408396
# 1  Andaman & Nicobar Islands  Huawei        11497       408396

# %%
## Creating a column to store brand usage ratio

Final_data['Brand_usage_ratio'] = Final_data['Brand users']/Final_data['Total users']

# %%
## Displaying the ratio of users using each device brand to the total number of registered users in each state

Device_brand_usage_ratio = Final_data[['State','Brand','Brand_usage_ratio']]
print("The ratio of users using each device brand to the total number of registered users in each state :")
Device_brand_usage_ratio.head()
# Out:
# The ratio of users using each device brand to the total number of registered users in each state :
#                        State     Brand  Brand_usage_ratio
# 0  Andaman & Nicobar Islands     Apple           0.022855
# 1  Andaman & Nicobar Islands    Huawei           0.028152
# 2  Andaman & Nicobar Islands    Lenovo           0.013129
# 3  Andaman & Nicobar Islands  Motorola           0.023240
# 4  Andaman & Nicobar Islands   OnePlus           0.037701

# %% [markdown]
# #### 3. Create a bar chart depicting the device brand usage ratio for each state.

# %%
## plotting a bar chart depicting the device brand usage ratio for each state in a single chart
plt.figure(figsize=(26,10))

sns.barplot(x='State',y='Brand_usage_ratio',  hue = 'Brand',data = Device_brand_usage_ratio)
plt.xticks(rotation=90)
plt.title('The device brand usage ratio for each state')
plt.xlabel('State')
plt.ylabel('Brand_usage_ratio')

plt.show()

# %% [markdown]
# #### Plotting 5 bar charts representing the device brand usage ratio (There are 7 states in each of the first 4 bar charts and 8 states in the last bar chart)

# %%
## data for the device brand usage ratio for first 7 states
first_7_state = Device_brand_usage_ratio.iloc[0:86]
first_7_state
# Out:
#                         State     Brand  Brand_usage_ratio
# 0   Andaman & Nicobar Islands     Apple           0.022855
# 1   Andaman & Nicobar Islands    Huawei           0.028152
# 2   Andaman & Nicobar Islands    Lenovo           0.013129
# 3   Andaman & Nicobar Islands  Motorola           0.023240
# 4   Andaman & Nicobar Islands   OnePlus           0.037701
# ..                        ...       ...                ...
# 81               Chhattisgarh    Others           0.078625
# 82               Chhattisgarh    Realme           0.067657
# 83               Chhattisgarh   Samsung           0.170479
# 84               Chhattisgarh      Vivo           0.209114
# 85               Chhattisgarh    Xiaomi           0.234012
#
# [86 rows x 3 columns]

# %%
## plotting bar chart representing the device brand usage ratio for first 7 states in the data
plt.figure(figsize=(26,10))

sns.barplot(x='State',y='Brand_usage_ratio',  hue = 'Brand',data = first_7_state)
plt.xticks(rotation=90)
plt.title('The device brand usage ratio for first 7 states')
plt.xlabel('State')
plt.ylabel('Brand_usage_ratio')

plt.show()

# %%
## data for the device brand usage ratio for second 7 states
second_7_state = Device_brand_usage_ratio.iloc[86:169]
second_7_state
# Out:
#                                     State     Brand  Brand_usage_ratio
# 86   Dadra & Nagar Haveli and Daman & Diu     Apple           0.019454
# 87   Dadra & Nagar Haveli and Daman & Diu    Huawei           0.015912
# 88   Dadra & Nagar Haveli and Daman & Diu    Lenovo           0.018241
# 89   Dadra & Nagar Haveli and Daman & Diu  Micromax           0.000314
# 90   Dadra & Nagar Haveli and Daman & Diu  Motorola           0.018493
# ..                                    ...       ...                ...
# 164                       Jammu & Kashmir    Others           0.072763
# 165                       Jammu & Kashmir    Realme           0.044938
# 166                       Jammu & Kashmir   Samsung           0.214183
# 167                       Jammu & Kashmir      Vivo           0.136911
# 168                       Jammu & Kashmir    Xiaomi           0.355849
#
# [83 rows x 3 columns]

# %%
## plotting bar chart representing the device brand usage ratio for second 7 states in the data
plt.figure(figsize=(26,10))

sns.barplot(x='State',y='Brand_usage_ratio',  hue = 'Brand',data = second_7_state)
plt.xticks(rotation=90)
plt.title('The device brand usage ratio for second 7 states')
plt.xlabel('State')
plt.ylabel('Brand_usage_ratio')

plt.show()

# %%
## data for the device brand usage ratio for third 7 states
third_7_state = Device_brand_usage_ratio.iloc[169:254]
third_7_state
# Out:
#            State    Brand  Brand_usage_ratio
# 169    Jharkhand    Apple           0.011937
# 170    Jharkhand     Asus           0.001016
# 171    Jharkhand   Gionee           0.005740
# 172    Jharkhand   Huawei           0.012509
# 173    Jharkhand   Lenovo           0.016730
# ..           ...      ...                ...
# 249  Maharashtra   Others           0.075299
# 250  Maharashtra   Realme           0.041420
# 251  Maharashtra  Samsung           0.219818
# 252  Maharashtra     Vivo           0.167800
# 253  Maharashtra   Xiaomi           0.254231
#
# [85 rows x 3 columns]

# %%
## plotting bar chart representing the device brand usage ratio for third 7 states in the data
plt.figure(figsize=(26,10))

sns.barplot(x='State',y='Brand_usage_ratio',  hue = 'Brand',data = third_7_state)
plt.xticks(rotation=90)
plt.title('The device brand usage ratio for third 7 states')
plt.xlabel('State')
plt.ylabel('Brand_usage_ratio')

plt.show()

# %%
## data for the device brand usage ratio for fourth 7 states
fourth_7_state = Device_brand_usage_ratio.iloc[254:344]
fourth_7_state
# Out:
#        State       Brand  Brand_usage_ratio
# 254  Manipur       Apple           0.024395
# 255  Manipur      Gionee           0.001632
# 256  Manipur  HMD Global           0.000946
# 257  Manipur      Huawei           0.011701
# 258  Manipur      Lenovo           0.006205
# ..       ...         ...                ...
# 339   Punjab      Realme           0.035529
# 340   Punjab     Samsung           0.226032
# 341   Punjab       Tecno           0.001756
# 342   Punjab        Vivo           0.177164
# 343   Punjab      Xiaomi           0.241518
#
# [90 rows x 3 columns]

# %%
## plotting bar chart representing the device brand usage ratio for fourth 7 states in the data
plt.figure(figsize=(26,12))

sns.barplot(x='State',y='Brand_usage_ratio',  hue = 'Brand',data = fourth_7_state)
plt.xticks(rotation=90)
plt.title('The device brand usage ratio for fourth 7 states')
plt.xlabel('State')
plt.ylabel('Brand_usage_ratio')

plt.show()

# %%
## data for the device brand usage ratio for last 8 states
last_8_state = Device_brand_usage_ratio.iloc[344:448]
last_8_state
# Out:
#            State     Brand  Brand_usage_ratio
# 344    Rajasthan     Apple           0.022063
# 345    Rajasthan    Gionee           0.012078
# 346    Rajasthan    Huawei           0.016780
# 347    Rajasthan    Lenovo           0.000955
# 348    Rajasthan  Motorola           0.008171
# ..           ...       ...                ...
# 443  West Bengal    Others           0.121508
# 444  West Bengal    Realme           0.064628
# 445  West Bengal   Samsung           0.211563
# 446  West Bengal      Vivo           0.130025
# 447  West Bengal    Xiaomi           0.265288
#
# [104 rows x 3 columns]

# %%
## plotting bar chart representing the device brand usage ratio for last 8 states in the data
plt.figure(figsize=(26,12))

sns.barplot(x='State',y='Brand_usage_ratio',  hue = 'Brand',data = last_8_state)
plt.xticks(rotation=90)
plt.title('The device brand usage ratio for last 8 states')
plt.xlabel('State')
plt.ylabel('Brand_usage_ratio')

plt.show()

# %% [markdown]
# # Task 5: Data Visualization

# %% [markdown]
# ## Question 5.1: Plot the total transactions and amount over time for a selected state.

# %% [markdown]
# #### 1. Create a line plot showing the total number of transactions and the total transaction amount over time (years and quarters) for a selected state.

# %%
## Creating the data showing the total number of transactions and the total transaction amount over time (years and quarters) for West Bengal
West_Bengal_data = State_txn_and_users[State_txn_and_users['State']=='West Bengal']
West_Bengal_data['Year_Qtr'] = West_Bengal_data['Year'].astype(str)+'-'+West_Bengal_data['Quarter'].astype(str)
West_Bengal_data.head()
# Out:
# C:\Users\nayan\AppData\Local\Temp\ipykernel_71896\3791418562.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   West_Bengal_data['Year_Qtr'] = West_Bengal_data['Year'].astype(str)+'-'+West_Bengal_data['Quarter'].astype(str)
#            State  Year  Quarter  Transactions  Amount (INR)    ATV (INR)  \
# 490  West Bengal  2018        1      11710225  1.062598e+10   907.410280
# 491  West Bengal  2018        2      18082446  1.862918e+10  1030.235814
# 492  West Bengal  2018        3      53705416  4.184393e+10   779.138070
# 493  West Bengal  2018        4      36513548  4.048962e+10  1108.893039
# 494  West Bengal  2019        1      47626388  5.016467e+10  1053.295762
#
#      Registered Users  App Opens Year_Qtr
# ...

# %%
## plotting a line chart showing the total number of transactions and the total transaction amount over time together for West Bengal
West_Bengal_data.plot(x='Year_Qtr',y=['Transactions','Amount (INR)'],marker = 'v',color=['red','green'],figsize=(8,4))

plt.title('The total number of transactions and the total transaction amount over time (years and quarters) for West Bengal')
plt.xlabel('Year_Qtr')
plt.ylabel('units')

plt.grid(True)
plt.show()

# %%
## plotting a line chart showing only the total number of transactions over time for West Bengal

West_Bengal_data.plot(x='Year_Qtr',y='Transactions',marker = '*', color='green',figsize=(8,4))
plt.title('The total number of transactions over time (years and quarters) for West Bengal')
plt.xlabel('Year_Qtr')
plt.ylabel('Transactions')

plt.grid(True)
plt.show()

# %%
## plotting a line chart showing only the total transaction amount over time for West Bengal

West_Bengal_data.plot(x='Year_Qtr',y='Amount (INR)',marker = '*', color='red',figsize=(8,4))
plt.title('The total transaction amount over time (years and quarters) for West Bengal')
plt.xlabel('Year_Qtr')
plt.ylabel('Amount (INR)')

plt.grid(True)
plt.show()

# %% [markdown]
# ## Question 5.2: Create a pie chart showing the distribution of transaction types for a specific quarter

# %% [markdown]
# #### 1. Create a pie chart showing the distribution of different transaction types for a selected state and quarter.

# %%
## Creating the required data for the first quarter of 2018 and for the state of Telangana
year_data = State_txnsplit[State_txnsplit['Year']==2018]
qtr_data = year_data[year_data['Quarter']==1]
T_data = qtr_data[qtr_data['State']=='Telangana']
T_data
# Out:
#           State  Year  Quarter          Transaction Type  Transactions  \
# 2164  Telangana  2018        1  Recharge & bill payments       4209319
# 2165  Telangana  2018        1     Peer-to-peer payments       3307245
# 2166  Telangana  2018        1         Merchant payments        351474
# 2167  Telangana  2018        1        Financial Services        262876
# 2168  Telangana  2018        1                    Others        391852
#
#       Amount (INR)    ATV (INR)
# 2164  8.319128e+08   197.635952
# 2165  1.174827e+10  3552.282625
# 2166  2.828991e+08   804.893297
# 2167  5.701188e+07   216.877445
# 2168  3.881115e+08   990.454197

# %%
## Creating the pie chart
plt.figure(figsize=(10,5))

plt.pie(T_data['Transactions'], labels=T_data['Transaction Type'], autopct='%1.1f%%', colors=['green','red','blue','yellow','grey'],startangle=90)


plt.title('The distribution of different transaction types for Telangana')
plt.show()

# %% [markdown]
# ## Question 5.3: Visualize the population density of districts in a selected state

# %% [markdown]
# #### 1. Create a bar plot showing the population density of districts in a selected state.

# %%
## Finding the required data for Uttar Pradesh
UP_data = District_demographics[District_demographics['State']=='Uttar Pradesh']
UP_data.head()
# Out:
#              State        District Headquarters  Population  Area (sq km)  \
# 586  Uttar Pradesh            Agra         Agra     4380793          4027
# 587  Uttar Pradesh         Aligarh      Aligarh     3673849          3747
# 588  Uttar Pradesh       Allahabad    Allahabad     5959798          5481
# 589  Uttar Pradesh  Ambedkar Nagar     Akbarpur     2398709          2372
# 590  Uttar Pradesh          Amethi    Gauriganj     2549935          3063
#
#      Density  Code  Alternate Name
# 586     1084  UP01            Agra
# 587     1007  UP02         Aligarh
# 588     1087  UP03       Prayagraj
# 589     1021  UP04  Ambedkar Nagar
# 590      830  UP05          Amethi

# %%
## plotting the bar chart
plt.figure(figsize=(16,4))

sns.barplot(UP_data,x='District',y='Density',color = 'green')
plt.xticks(rotation=90)
plt.title('the population density of districts in Uttar Pradesh')
plt.xlabel('District')
plt.ylabel('Population Density')

plt.show()

# %% [markdown]
# # Task 6: Insights and Conclusions [Advanced Section]

# %% [markdown]
# ## Question 6.1: Identify any trends or patterns in the transaction data

# %% [markdown]
# #### 1. Analyze the transaction data to identify any noticeable trends or patterns. Summarize your findings.

# %%
## Creating the data to plot line charts to show the trends of transaction data over time (years and quarters)
txn_amt_data = State_txn_and_users[['State','Year','Quarter','Transactions','Amount (INR)']]
txn_amt_data['Year_Qtr']=txn_amt_data['Year'].astype(str)+'-'+txn_amt_data['Quarter'].astype(str)
# Out:
# C:\Users\nayan\AppData\Local\Temp\ipykernel_71896\2963096039.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   txn_amt_data['Year_Qtr']=txn_amt_data['Year'].astype(str)+'-'+txn_amt_data['Quarter'].astype(str)

# %%
## Creating the data for plotting the trend of transaction value over time
amt_data = txn_amt_data.groupby('Year_Qtr').aggregate({'Amount (INR)':'sum'})
amt_data.reset_index('Year_Qtr',inplace=True)

# %%
## plotting the line chart for the trend of transaction value over time
amt_data.plot(x='Year_Qtr',y='Amount (INR)',marker ='*',color='purple',figsize=(8,4))
plt.title('Trend of the total transaction value over time')
plt.xlabel('Year_Qtr')
plt.ylabel('Transaction Amount (INR)')

plt.grid(True)
plt.show()

# %%
## Creating the data for plotting the trend of transaction volume over time
txn_data = txn_amt_data.groupby('Year_Qtr').aggregate({'Transactions':'sum'})
txn_data.reset_index('Year_Qtr',inplace=True)

# %%
## plotting the line chart for the trend of transaction volume over time
txn_data.plot(x='Year_Qtr',y='Transactions',marker ='*',color='blue',figsize=(8,4))
plt.title('Trend of the transactions volume over time')
plt.xlabel('Year_Qtr')
plt.ylabel('Transactions')

plt.grid(True)
plt.show()

# %% [markdown]
# ### Findings:

# %% [markdown]
# #### The Transaction value i.e. the total transaction amount was increasing steadily from the first quarter of the year 2018 but it was slightly decreasing from the first quarter of the year 2020. And it was again increasing exponentially from the second quarter of the year 2020.

# %% [markdown]
# #### The Transaction volume i.e. the total number of transactions has the same trend as the transaction amount.

# %% [markdown]
# ## Question 6.2: Correlate demographic data with transaction data

# %% [markdown]
# #### 1. Find correlations between demographic data (e.g., population density) and transaction data (e.g., transaction volume). Summarize your findings.

# %%
## Merging the datasets
Merged_data = pd.merge(District_txn_and_users, District_demographics, left_on = 'Code', right_on = 'Code', how = 'outer')

# %%
## Formatting the merged dataset
Merged_data.dropna(inplace=True)
Merged_data.rename(columns={'State_y':'State','District_y':'District'},inplace=True)
Merged_data.head(2)
# Out:
#                      State_x    Year  Quarter District_x  Code  Transactions  \
# 0  Andaman & Nicobar Islands  2018.0      1.0   Nicobars  AN01         528.0
# 1  Andaman & Nicobar Islands  2018.0      2.0   Nicobars  AN01        1120.0
#
#    Amount (INR)    ATV (INR)  Registered Users  App Opens  \
# 0   1139848.801  2158.804548             262.0        0.0
# 1   3072436.908  2743.247239             351.0        0.0
#
#                        State District Headquarters  Population  Area (sq km)  \
# 0  Andaman & Nicobar Islands  Nicobar  Car Nicobar     36842.0        1841.0
# 1  Andaman & Nicobar Islands  Nicobar  Car Nicobar     36842.0        1841.0
#
#    Density Alternate Name
# 0     20.0       Nicobars
# 1     20.0       Nicobars

# %%
## data to calculate the correlation of population density with transaction volume
data = Merged_data[['State','District','Density','Transactions']]
txn_data=data.groupby(['State','District']).aggregate({'Transactions':'sum'})
district_txn_data = pd.merge(data,txn_data,left_on=['State','District'],right_on=['State','District'],how='outer')
district_txn_data.head(2)
# Out:
#                        State District  Density  Transactions_x  Transactions_y
# 0  Andaman & Nicobar Islands  Nicobar     20.0           528.0         59387.0
# 1  Andaman & Nicobar Islands  Nicobar     20.0          1120.0         59387.0

# %%
## Formatting the data
district_txn_data.drop(columns='Transactions_x',inplace=True)
print(district_txn_data.head(2))

district_txn_data.drop_duplicates(inplace=True)
print(district_txn_data.head(2))

district_txn_data.rename(columns={'Density':'Population_Density','Transactions_y':'Transaction_Volume'},inplace=True)
print(district_txn_data.head(2))
# Out:
#                        State District  Density  Transactions_y
# 0  Andaman & Nicobar Islands  Nicobar     20.0         59387.0
# 1  Andaman & Nicobar Islands  Nicobar     20.0         59387.0
#                         State                  District  Density  \
# 0   Andaman & Nicobar Islands                   Nicobar     20.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman     28.0
#
#     Transactions_y
# 0          59387.0
# 14        149394.0
#                         State                  District  Population_Density  \
# 0   Andaman & Nicobar Islands                   Nicobar                20.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman                28.0
#
#     Transaction_Volume
# 0              59387.0
# 14            149394.0

# %%
## Calculating correlation
district_txn_data.corr(numeric_only = True)
# Out:
#                     Population_Density  Transaction_Volume
# Population_Density            1.000000            0.250399
# Transaction_Volume            0.250399            1.000000

# %%
## plotting a scatterplot to find the correlation between population density and transaction volume
plt.figure(figsize=(3,3))

sns.scatterplot(data=district_txn_data, x='Population_Density', y='Transaction_Volume')
plt.xticks(rotation=90)
plt.title('Population_Density vs Transaction_Volume')
plt.xlabel('Population_Density')
plt.ylabel('Transaction_Volume')

plt.show()

# %%
## data to calculate the correlation of population density with transaction amount
data = Merged_data[['State','District','Density','Amount (INR)']]
amt_data=data.groupby(['State','District']).aggregate({'Amount (INR)':'sum'})
district_amt_data = pd.merge(data,amt_data,left_on=['State','District'],right_on=['State','District'],how='outer')
district_amt_data.head(2)
# Out:
#                        State District  Density  Amount (INR)_x  Amount (INR)_y
# 0  Andaman & Nicobar Islands  Nicobar     20.0     1139848.801    2.290015e+08
# 1  Andaman & Nicobar Islands  Nicobar     20.0     3072436.908    2.290015e+08

# %%
## Formatting the data
district_amt_data.drop(columns='Amount (INR)_x',inplace=True)
print(district_amt_data.head(2))

district_amt_data.drop_duplicates(inplace=True)
print(district_amt_data.head(2))

district_amt_data.rename(columns={'Density':'Population_Density','Amount (INR)_y':'Amount (INR)'},inplace=True)
print(district_amt_data.head(2))
# Out:
#                        State District  Density  Amount (INR)_y
# 0  Andaman & Nicobar Islands  Nicobar     20.0    2.290015e+08
# 1  Andaman & Nicobar Islands  Nicobar     20.0    2.290015e+08
#                         State                  District  Density  \
# 0   Andaman & Nicobar Islands                   Nicobar     20.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman     28.0
#
#     Amount (INR)_y
# 0     2.290015e+08
# 14    3.631200e+08
#                         State                  District  Population_Density  \
# 0   Andaman & Nicobar Islands                   Nicobar                20.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman                28.0
#
#     Amount (INR)
# 0   2.290015e+08
# 14  3.631200e+08

# %%
## Calculating correlation
district_amt_data.corr(numeric_only = True)
# Out:
#                     Population_Density  Amount (INR)
# Population_Density            1.000000      0.286639
# Amount (INR)                  0.286639      1.000000

# %%
## plotting a scatterplot to find the correlation between population density and transaction amount
plt.figure(figsize=(3,3))

sns.scatterplot(data=district_amt_data, x='Population_Density', y='Amount (INR)')
plt.xticks(rotation=90)
plt.title('Population Density vs Transaction Amount')
plt.xlabel('Population Density')
plt.ylabel('Transaction Amount')

plt.show()

# %%
## data to calculate the correlation of population density with registered users
data = Merged_data[['State','District','Density','Registered Users']]
users_data=data.groupby(['State','District']).aggregate({'Registered Users':'sum'})
district_users_data = pd.merge(data,users_data,left_on=['State','District'],right_on=['State','District'],how='outer')
district_users_data.head(2)
# Out:
#                        State District  Density  Registered Users_x  \
# 0  Andaman & Nicobar Islands  Nicobar     20.0               262.0
# 1  Andaman & Nicobar Islands  Nicobar     20.0               351.0
#
#    Registered Users_y
# 0             12179.0
# 1             12179.0

# %%
## Formatting the data
district_users_data.drop(columns='Registered Users_x',inplace=True)
print(district_users_data.head(2))

district_users_data.drop_duplicates(inplace=True)
print(district_users_data.head(2))

district_users_data.rename(columns={'Density':'Population Density','Registered Users_y':'Registered users'},inplace=True)
print(district_users_data.head(2))
# Out:
#                        State District  Density  Registered Users_y
# 0  Andaman & Nicobar Islands  Nicobar     20.0             12179.0
# 1  Andaman & Nicobar Islands  Nicobar     20.0             12179.0
#                         State                  District  Density  \
# 0   Andaman & Nicobar Islands                   Nicobar     20.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman     28.0
#
#     Registered Users_y
# 0              12179.0
# 14             50523.0
#                         State                  District  Population Density  \
# 0   Andaman & Nicobar Islands                   Nicobar                20.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman                28.0
#
#     Registered users
# 0            12179.0
# 14           50523.0

# %%
## Calculating correlation
district_users_data.corr(numeric_only = True)
# Out:
#                     Population Density  Registered users
# Population Density            1.000000          0.289293
# Registered users              0.289293          1.000000

# %%
## plotting a scatterplot to find the correlation between population density and total registered users
plt.figure(figsize=(3,3))

sns.scatterplot(data=district_users_data, x='Population Density', y='Registered users')
plt.xticks(rotation=90)
plt.title('Population Density vs Registered users')
plt.xlabel('Population Density')
plt.ylabel('Registered users')

plt.show()

# %%
## data to calculate the correlation of population density with the number of app opens
data = Merged_data[['State','District','Density','App Opens']]
app_data=data.groupby(['State','District']).aggregate({'App Opens':'sum'})
district_app_data = pd.merge(data,app_data,left_on=['State','District'],right_on=['State','District'],how='outer')
district_app_data.head(2)
# Out:
#                        State District  Density  App Opens_x  App Opens_y
# 0  Andaman & Nicobar Islands  Nicobar     20.0          0.0     537622.0
# 1  Andaman & Nicobar Islands  Nicobar     20.0          0.0     537622.0

# %%
## Formatting the data
district_app_data.drop(columns='App Opens_x',inplace=True)
print(district_app_data.head(2))

district_app_data.drop_duplicates(inplace=True)
print(district_app_data.head(2))

district_app_data.rename(columns={'Density':'Population Density','App Opens_y':'App Opens'},inplace=True)
print(district_app_data.head(2))
# Out:
#                        State District  Density  App Opens_y
# 0  Andaman & Nicobar Islands  Nicobar     20.0     537622.0
# 1  Andaman & Nicobar Islands  Nicobar     20.0     537622.0
#                         State                  District  Density  App Opens_y
# 0   Andaman & Nicobar Islands                   Nicobar     20.0     537622.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman     28.0    1062201.0
#                         State                  District  Population Density  \
# 0   Andaman & Nicobar Islands                   Nicobar                20.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman                28.0
#
#     App Opens
# 0    537622.0
# 14  1062201.0

# %%
## Calculating correlation
district_app_data.corr(numeric_only = True)
# Out:
#                     Population Density  App Opens
# Population Density            1.000000   0.179848
# App Opens                     0.179848   1.000000

# %%
## plotting a scatterplot to find the correlation between population density and the number of app opens
plt.figure(figsize=(3,3))

sns.scatterplot(data=district_app_data, x='Population Density', y='App Opens')
plt.xticks(rotation=90)
plt.title('Population Density vs App opens')
plt.xlabel('Population Density')
plt.ylabel('App Opens')

plt.show()

# %%
## data to calculate the correlation of population with transaction volume
data = Merged_data[['State','District','Population','Transactions']]
txn_population_data=data.groupby(['State','District']).aggregate({'Transactions':'sum'})
district_txn_population_data = pd.merge(data,txn_population_data,left_on=['State','District'],right_on=['State','District'],how='outer')
district_txn_population_data.head(2)
# Out:
#                        State District  Population  Transactions_x  \
# 0  Andaman & Nicobar Islands  Nicobar     36842.0           528.0
# 1  Andaman & Nicobar Islands  Nicobar     36842.0          1120.0
#
#    Transactions_y
# 0         59387.0
# 1         59387.0

# %%
## Formatting the data
district_txn_population_data.drop(columns='Transactions_x',inplace=True)
print(district_txn_population_data.head(2))

district_txn_population_data.drop_duplicates(inplace=True)
print(district_txn_population_data.head(2))

district_txn_population_data.rename(columns={'Transactions_y':'Transaction_Volume'},inplace=True)
print(district_txn_population_data.head(2))
# Out:
#                        State District  Population  Transactions_y
# 0  Andaman & Nicobar Islands  Nicobar     36842.0         59387.0
# 1  Andaman & Nicobar Islands  Nicobar     36842.0         59387.0
#                         State                  District  Population  \
# 0   Andaman & Nicobar Islands                   Nicobar     36842.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman    105597.0
#
#     Transactions_y
# 0          59387.0
# 14        149394.0
#                         State                  District  Population  \
# 0   Andaman & Nicobar Islands                   Nicobar     36842.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman    105597.0
#
#     Transaction_Volume
# 0              59387.0
# 14            149394.0

# %%
## Calculating correlation
district_txn_population_data.corr(numeric_only = True)
# Out:
#                     Population  Transaction_Volume
# Population            1.000000            0.468856
# Transaction_Volume    0.468856            1.000000

# %%
## plotting a scatterplot to find the correlation between Population and transaction volume
plt.figure(figsize=(3,3))

sns.scatterplot(data=district_txn_population_data, x='Population', y='Transaction_Volume')
plt.xticks(rotation=90)
plt.title('Population vs Transaction_Volume')
plt.xlabel('Population')
plt.ylabel('Transaction_Volume')

plt.show()

# %%
## data to calculate the correlation of population with Transaction amount
data = Merged_data[['State','District','Population','Amount (INR)']]
amt_population_data=data.groupby(['State','District']).aggregate({'Amount (INR)':'sum'})
district_amt_population_data = pd.merge(data,amt_population_data,left_on=['State','District'],right_on=['State','District'],how='outer')
district_amt_population_data.head(2)
# Out:
#                        State District  Population  Amount (INR)_x  \
# 0  Andaman & Nicobar Islands  Nicobar     36842.0     1139848.801
# 1  Andaman & Nicobar Islands  Nicobar     36842.0     3072436.908
#
#    Amount (INR)_y
# 0    2.290015e+08
# 1    2.290015e+08

# %%
## Formatting the data
district_amt_population_data.drop(columns='Amount (INR)_x',inplace=True)
print(district_amt_population_data.head(2))

district_amt_population_data.drop_duplicates(inplace=True)
print(district_amt_population_data.head(2))

district_amt_population_data.rename(columns={'Amount (INR)_y':'Amount (INR)'},inplace=True)
print(district_amt_population_data.head(2))
# Out:
#                        State District  Population  Amount (INR)_y
# 0  Andaman & Nicobar Islands  Nicobar     36842.0    2.290015e+08
# 1  Andaman & Nicobar Islands  Nicobar     36842.0    2.290015e+08
#                         State                  District  Population  \
# 0   Andaman & Nicobar Islands                   Nicobar     36842.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman    105597.0
#
#     Amount (INR)_y
# 0     2.290015e+08
# 14    3.631200e+08
#                         State                  District  Population  \
# 0   Andaman & Nicobar Islands                   Nicobar     36842.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman    105597.0
#
#     Amount (INR)
# 0   2.290015e+08
# 14  3.631200e+08

# %%
## Calculating correlation
district_amt_population_data.corr(numeric_only = True)
# Out:
#               Population  Amount (INR)
# Population      1.000000      0.490988
# Amount (INR)    0.490988      1.000000

# %%
## plotting a scatterplot to find the correlation between Population and transaction amount
plt.figure(figsize=(3,3))

sns.scatterplot(data=district_amt_population_data, x='Population', y='Amount (INR)')
plt.xticks(rotation=90)
plt.title('Population vs Transaction Amount')
plt.xlabel('Population')
plt.ylabel('Transaction Amount')

plt.show()

# %%
## data to calculate the correlation of population with Registered users
data = Merged_data[['State','District','Population','Registered Users']]
users_population_data=data.groupby(['State','District']).aggregate({'Registered Users':'sum'})
district_users_population_data = pd.merge(data,users_population_data,left_on=['State','District'],right_on=['State','District'],how='outer')
district_users_population_data.head(2)
# Out:
#                        State District  Population  Registered Users_x  \
# 0  Andaman & Nicobar Islands  Nicobar     36842.0               262.0
# 1  Andaman & Nicobar Islands  Nicobar     36842.0               351.0
#
#    Registered Users_y
# 0             12179.0
# 1             12179.0

# %%
## Formatting the data
district_users_population_data.drop(columns='Registered Users_x',inplace=True)
print(district_users_population_data.head(2))

district_users_population_data.drop_duplicates(inplace=True)
print(district_users_population_data.head(2))

district_users_population_data.rename(columns={'Registered Users_y':'Registered users'},inplace=True)
print(district_users_population_data.head(2))
# Out:
#                        State District  Population  Registered Users_y
# 0  Andaman & Nicobar Islands  Nicobar     36842.0             12179.0
# 1  Andaman & Nicobar Islands  Nicobar     36842.0             12179.0
#                         State                  District  Population  \
# 0   Andaman & Nicobar Islands                   Nicobar     36842.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman    105597.0
#
#     Registered Users_y
# 0              12179.0
# 14             50523.0
#                         State                  District  Population  \
# 0   Andaman & Nicobar Islands                   Nicobar     36842.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman    105597.0
#
#     Registered users
# 0            12179.0
# 14           50523.0

# %%
## Calculating correlation
district_users_population_data.corr(numeric_only = True)
# Out:
#                   Population  Registered users
# Population           1.00000           0.70733
# Registered users     0.70733           1.00000

# %%
## plotting a scatterplot to find the correlation between Population and the number of registered users
plt.figure(figsize=(3,3))

sns.scatterplot(data=district_users_population_data, x='Population', y='Registered users')
plt.xticks(rotation=90)
plt.title('Population vs Registered users')
plt.xlabel('Population')
plt.ylabel('Registered users')

plt.show()

# %%
## data to calculate the correlation of population with the number of App Opens
data = Merged_data[['State','District','Population','App Opens']]
app_population_data=data.groupby(['State','District']).aggregate({'App Opens':'sum'})
district_app_population_data = pd.merge(data,app_population_data,left_on=['State','District'],right_on=['State','District'],how='outer')
district_app_population_data.head(2)
# Out:
#                        State District  Population  App Opens_x  App Opens_y
# 0  Andaman & Nicobar Islands  Nicobar     36842.0          0.0     537622.0
# 1  Andaman & Nicobar Islands  Nicobar     36842.0          0.0     537622.0

# %%
## Formatting the data
district_app_population_data.drop(columns='App Opens_x',inplace=True)
print(district_app_population_data.head(2))

district_app_population_data.drop_duplicates(inplace=True)
print(district_app_population_data.head(2))

district_app_population_data.rename(columns={'App Opens_y':'App Opens'},inplace=True)
print(district_app_population_data.head(2))
# Out:
#                        State District  Population  App Opens_y
# 0  Andaman & Nicobar Islands  Nicobar     36842.0     537622.0
# 1  Andaman & Nicobar Islands  Nicobar     36842.0     537622.0
#                         State                  District  Population  \
# 0   Andaman & Nicobar Islands                   Nicobar     36842.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman    105597.0
#
#     App Opens_y
# 0      537622.0
# 14    1062201.0
#                         State                  District  Population  App Opens
# 0   Andaman & Nicobar Islands                   Nicobar     36842.0   537622.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman    105597.0  1062201.0

# %%
## Calculating correlation
district_app_population_data.corr(numeric_only = True)
# Out:
#             Population  App Opens
# Population    1.000000   0.560929
# App Opens     0.560929   1.000000

# %%
## plotting a scatterplot to find the correlation between Population and the number of App opens
plt.figure(figsize=(3,3))

sns.scatterplot(data=district_app_population_data, x='Population', y='App Opens')
plt.xticks(rotation=90)
plt.title('Population vs the number of App opens')
plt.xlabel('Population')
plt.ylabel('the number of App Opens')

plt.show()

# %%
## data to calculate the correlation of Area with Transaction volume
data = Merged_data[['State','District','Area (sq km)','Transactions']]
txn_area_data=data.groupby(['State','District']).aggregate({'Transactions':'sum'})
district_txn_area_data = pd.merge(data,txn_area_data,left_on=['State','District'],right_on=['State','District'],how='outer')
district_txn_area_data.head(2)
# Out:
#                        State District  Area (sq km)  Transactions_x  \
# 0  Andaman & Nicobar Islands  Nicobar        1841.0           528.0
# 1  Andaman & Nicobar Islands  Nicobar        1841.0          1120.0
#
#    Transactions_y
# 0         59387.0
# 1         59387.0

# %%
## Formatting the data
district_txn_area_data.drop(columns='Transactions_x',inplace=True)
print(district_txn_area_data.head(2))

district_txn_area_data.drop_duplicates(inplace=True)
print(district_txn_area_data.head(2))

district_txn_area_data.rename(columns={'Transactions_y':'Transaction_Volume'},inplace=True)
print(district_txn_area_data.head(2))
# Out:
#                        State District  Area (sq km)  Transactions_y
# 0  Andaman & Nicobar Islands  Nicobar        1841.0         59387.0
# 1  Andaman & Nicobar Islands  Nicobar        1841.0         59387.0
#                         State                  District  Area (sq km)  \
# 0   Andaman & Nicobar Islands                   Nicobar        1841.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman        3736.0
#
#     Transactions_y
# 0          59387.0
# 14        149394.0
#                         State                  District  Area (sq km)  \
# 0   Andaman & Nicobar Islands                   Nicobar        1841.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman        3736.0
#
#     Transaction_Volume
# 0              59387.0
# 14            149394.0

# %%
## Calculating correlation
district_txn_area_data.corr(numeric_only = True)
# Out:
#                     Area (sq km)  Transaction_Volume
# Area (sq km)            1.000000            0.072991
# Transaction_Volume      0.072991            1.000000

# %%
## plotting a scatterplot to find the correlation between Area and transaction volume
plt.figure(figsize=(3,3))

sns.scatterplot(data=district_txn_area_data, x='Area (sq km)', y='Transaction_Volume')
plt.xticks(rotation=90)
plt.title('Area vs Transaction_Volume')
plt.xlabel('Area (sq km)')
plt.ylabel('Transaction_Volume')

plt.show()

# %%
## data to calculate the correlation of Area with Transaction amount
data = Merged_data[['State','District','Area (sq km)','Amount (INR)']]
amt_area_data=data.groupby(['State','District']).aggregate({'Amount (INR)':'sum'})
district_amt_area_data = pd.merge(data,amt_area_data,left_on=['State','District'],right_on=['State','District'],how='outer')
district_amt_area_data.head(2)
# Out:
#                        State District  Area (sq km)  Amount (INR)_x  \
# 0  Andaman & Nicobar Islands  Nicobar        1841.0     1139848.801
# 1  Andaman & Nicobar Islands  Nicobar        1841.0     3072436.908
#
#    Amount (INR)_y
# 0    2.290015e+08
# 1    2.290015e+08

# %%
## Formatting the data
district_amt_area_data.drop(columns='Amount (INR)_x',inplace=True)
print(district_amt_area_data.head(2))

district_amt_area_data.drop_duplicates(inplace=True)
print(district_amt_area_data.head(2))

district_amt_area_data.rename(columns={'Amount (INR)_y':'Amount (INR)'},inplace=True)
print(district_amt_area_data.head(2))
# Out:
#                        State District  Area (sq km)  Amount (INR)_y
# 0  Andaman & Nicobar Islands  Nicobar        1841.0    2.290015e+08
# 1  Andaman & Nicobar Islands  Nicobar        1841.0    2.290015e+08
#                         State                  District  Area (sq km)  \
# 0   Andaman & Nicobar Islands                   Nicobar        1841.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman        3736.0
#
#     Amount (INR)_y
# 0     2.290015e+08
# 14    3.631200e+08
#                         State                  District  Area (sq km)  \
# 0   Andaman & Nicobar Islands                   Nicobar        1841.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman        3736.0
#
#     Amount (INR)
# 0   2.290015e+08
# 14  3.631200e+08

# %%
## Calculating correlation
district_amt_area_data.corr(numeric_only = True)
# Out:
#               Area (sq km)  Amount (INR)
# Area (sq km)      1.000000      0.093488
# Amount (INR)      0.093488      1.000000

# %%
## plotting a scatterplot to find the correlation between Area and Transaction Amount
plt.figure(figsize=(3,3))

sns.scatterplot(data=district_amt_area_data, x='Area (sq km)', y='Amount (INR)')
plt.xticks(rotation=90)
plt.title('Area vs Transaction Amount')
plt.xlabel('Area (sq km)')
plt.ylabel('Transaction Amount')

plt.show()

# %%
## data to calculate the correlation of Area (sq km) with total Registered users
data = Merged_data[['State','District','Area (sq km)','Registered Users']]
users_area_data=data.groupby(['State','District']).aggregate({'Registered Users':'sum'})
district_users_area_data = pd.merge(data,users_area_data,left_on=['State','District'],right_on=['State','District'],how='outer')
district_users_area_data.head(2)
# Out:
#                        State District  Area (sq km)  Registered Users_x  \
# 0  Andaman & Nicobar Islands  Nicobar        1841.0               262.0
# 1  Andaman & Nicobar Islands  Nicobar        1841.0               351.0
#
#    Registered Users_y
# 0             12179.0
# 1             12179.0

# %%
## Formatting the data
district_users_area_data.drop(columns='Registered Users_x',inplace=True)
print(district_users_area_data.head(2))

district_users_area_data.drop_duplicates(inplace=True)
print(district_users_area_data.head(2))

district_users_area_data.rename(columns={'Registered Users_y':'Registered users'},inplace=True)
print(district_users_area_data.head(2))
# Out:
#                        State District  Area (sq km)  Registered Users_y
# 0  Andaman & Nicobar Islands  Nicobar        1841.0             12179.0
# 1  Andaman & Nicobar Islands  Nicobar        1841.0             12179.0
#                         State                  District  Area (sq km)  \
# 0   Andaman & Nicobar Islands                   Nicobar        1841.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman        3736.0
#
#     Registered Users_y
# 0              12179.0
# 14             50523.0
#                         State                  District  Area (sq km)  \
# 0   Andaman & Nicobar Islands                   Nicobar        1841.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman        3736.0
#
#     Registered users
# 0            12179.0
# 14           50523.0

# %%
## Calculating correlation
district_users_area_data.corr(numeric_only = True)
# Out:
#                   Area (sq km)  Registered users
# Area (sq km)          1.000000          0.143136
# Registered users      0.143136          1.000000

# %%
## plotting a scatterplot to find the correlation between Area and total Registered users
plt.figure(figsize=(3,3))

sns.scatterplot(data=district_users_area_data, x='Area (sq km)', y='Registered users')
plt.xticks(rotation=90)
plt.title('Area vs Registered users')
plt.xlabel('Area (sq km)')
plt.ylabel('Registered users')

plt.show()

# %%
## data to calculate the correlation of Area with the number of App Opens
data = Merged_data[['State','District','Area (sq km)','App Opens']]
app_area_data=data.groupby(['State','District']).aggregate({'App Opens':'sum'})
district_app_area_data = pd.merge(data,app_area_data,left_on=['State','District'],right_on=['State','District'],how='outer')
district_app_area_data.head(2)
# Out:
#                        State District  Area (sq km)  App Opens_x  App Opens_y
# 0  Andaman & Nicobar Islands  Nicobar        1841.0          0.0     537622.0
# 1  Andaman & Nicobar Islands  Nicobar        1841.0          0.0     537622.0

# %%
## Formatting the data
district_app_area_data.drop(columns='App Opens_x',inplace=True)
print(district_app_area_data.head(2))

district_app_area_data.drop_duplicates(inplace=True)
print(district_app_area_data.head(2))

district_app_area_data.rename(columns={'App Opens_y':'App Opens'},inplace=True)
print(district_app_area_data.head(2))
# Out:
#                        State District  Area (sq km)  App Opens_y
# 0  Andaman & Nicobar Islands  Nicobar        1841.0     537622.0
# 1  Andaman & Nicobar Islands  Nicobar        1841.0     537622.0
#                         State                  District  Area (sq km)  \
# 0   Andaman & Nicobar Islands                   Nicobar        1841.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman        3736.0
#
#     App Opens_y
# 0      537622.0
# 14    1062201.0
#                         State                  District  Area (sq km)  \
# 0   Andaman & Nicobar Islands                   Nicobar        1841.0
# 14  Andaman & Nicobar Islands  North and Middle Andaman        3736.0
#
#     App Opens
# 0    537622.0
# 14  1062201.0

# %%
## Calculating correlation
district_app_area_data.corr(numeric_only = True)
# Out:
#               Area (sq km)  App Opens
# Area (sq km)      1.000000   0.179051
# App Opens         0.179051   1.000000

# %%
## plotting a scatterplot to find the correlation between Area and the number of App opens
plt.figure(figsize=(3,3))

sns.scatterplot(data=district_app_area_data, x='Area (sq km)', y='App Opens')
plt.xticks(rotation=90)
plt.title('Area vs the number of App opens')
plt.xlabel('Area (sq km)')
plt.ylabel('the number of App Opens')

plt.show()

# %% [markdown]
# #### Findings :

# %% [markdown]
# #### From the above measurements of correlation coefficient and charts, we see that Population has strong relationship with the number of Registered users and the number of App Opens, i.e., when Population increases (or decreases), the number of Registered users and the number of App Opens highly increase (or decrease).
# #### Population has moderate relationship with the number of Transactions and the Transaction Amount, i.e., when Population increases (or decreases), the number of Transactions and the total Transaction Amount slightly increase (or decrease).
# #### Population Density and Area have weak relationship with the number of Transactions, the Transaction Amount, the number of Registered users and the number of App opens,i.e., when Population Density and Area increase (or decrease), the total number of Transactions, the Transaction Amount, the number of Registered users and the number of App Opens negligibly increase (or decrease).

# %% [markdown]
# ## Question 6.3: Summarize findings and insights

# %% [markdown]
# #### 1. Summarize the key findings and insights from your analysis. Provide actionable recommendations based on the data.

# %%
print("From the above analysis, we see that PhonePe has seen steady growth from early 2018.\nStarting with over 4 cr users in Q1 of 2018, it climbed past 30 cr by Q2 of 2021.\nThus, the above increase is clearly showing PhonePe's rising popularity as one of India's leading digital payment platforms.\nThe steady addition of users every quarter suggests that more people find its services useful and trustworthy for handling digital transactions.")
print("Here we see that Xiaomi is the only device brand with the highest number of registered users for each state except Sikkim.\nSo it is better to make some additional offers to use other brands to increase the number of users of other brands.")
print("We also see that there is very less number of transactions in Financial Services comparative to other transaction types in maximum number of states.\nSo some necessary steps should be taken to increase the number of transactions in Financial Services transaction type.")
# Out:
# From the above analysis, we see that PhonePe has seen steady growth from early 2018.
# Starting with over 4 cr users in Q1 of 2018, it climbed past 30 cr by Q2 of 2021.
# Thus, the above increase is clearly showing PhonePe's rising popularity as one of India's leading digital payment platforms.
# The steady addition of users every quarter suggests that more people find its services useful and trustworthy for handling digital transactions.
# Here we see that Xiaomi is the only device brand with the highest number of registered users for each state except Sikkim.
# So it is better to make some additional offers to use other brands to increase the number of users of other brands.
# We also see that there is very less number of transactions in Financial Services comparative to other transaction types in maximum number of states.
# So some necessary steps should be taken to increase the number of transactions in Financial Services transaction type.
